# %%
import numpy as py
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
indep=dataset[['Age','EstimatedSalary','Gender_Male']]

# %%
dep=dataset[['Purchased']]

# %%
indep.shape
# Out:
# (400, 3)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
param_grid={'criterion':["gini", "entropy", "log_loss"],'splitter':["best", "random"],'max_features':["sqrt", "log2"],'max_leaf_nodes':[2,4,6,8,10]}
grid=GridSearchCV(DecisionTreeClassifier(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,y_train)
re=grid.cv_results_
y_pred=grid.predict(X_test)
cm=confusion_matrix(y_test,y_pred)
clf_report=classification_report(y_test,y_pred)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits

# %%
print("The R_score value for best parameter():",format(grid.best_params_),clf_report) 
table=pd.DataFrame.from_dict(re)
table
# Out:
# The R_score value for best parameter(): {'criterion': 'log_loss', 'max_features': 'log2', 'max_leaf_nodes': 8, 'splitter': 'best'}               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.92        85
#            1       0.82      0.94      0.88        49
#
#     accuracy                           0.90       134
#    macro avg       0.89      0.91      0.90       134
# weighted avg       0.91      0.90      0.90       134
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006447      0.004481         0.022149        0.020953
# 1        0.055102      0.027172         0.064343        0.040011
# 2        0.015689      0.012300         0.012086        0.008624
# 3        0.000816      0.001000         0.012114        0.004078
# 4        0.006043      0.003357         0.008880        0.003511
# 5        0.008060      0.003116         0.018519        0.015922
# 6        0.016529      0.017944         0.010480        0.006426
# 7        0.006448      0.005316         0.009666        0.000816
# 8        0.009663      0.000811         0.008458        0.003214
# 9        0.006853      0.003937         0.008855        0.000996
# 10       0.004024      0.004929         0.009664        0.000808
# 11       0.003621      0.004481         0.008057        0.003113
# 12       0.004033      0.004939         0.011685        0.004309
# 13       0.006852      0.003938         0.009259        0.000989
# 14       0.015299      0.017855         0.020146        0.015614
# 15       0.013686      0.004470         0.022538        0.023923
# 16       0.006445      0.007785         0.010070        0.000010
# 17       0.011675      0.009976         0.008464        0.003214
# 18       0.007653      0.002954         0.006859        0.003937
# 19       0.006448      0.004482         0.007246        0.003735
# 20       0.008065      0.003116         0.010476        0.005763
# 21       0.007652      0.007475         0.008478        0.003226
# 22       0.009261      0.000998         0.006853        0.003938
# 23       0.006046      0.004937         0.012086        0.004025
# 24       0.007643      0.002949         0.008469        0.003466
# 25       0.008458      0.006663         0.010076        0.000007
# 26       0.010479      0.010384         0.007647        0.002950
# 27       0.006852      0.004867         0.009253        0.000990
# 28       0.006041      0.003361         0.006849        0.003934
# 29       0.006039      0.004931         0.007247        0.003735
# 30       0.002420      0.002951         0.010477        0.005754
# 31       0.006040      0.004931         0.009262        0.001001
# 32       0.008849      0.000997         0.006449        0.003680
# 33       0.004027      0.004219         0.010082        0.000016
# 34       0.007245      0.003733         0.008065        0.003120
# 35       0.007653      0.002956         0.006851        0.003936
# 36       0.006052      0.004226         0.010064        0.000003
# 37       0.004431      0.004659         0.009675        0.000806
# 38       0.007654      0.003905         0.008467        0.003218
# 39       0.006052      0.004225         0.008458        0.003218
# 40       0.005642      0.002949         0.007263        0.007153
# 41       0.006444      0.003679         0.008063        0.003114
# 42       0.015302      0.007709         0.006864        0.003944
# 43       0.006041      0.004932         0.007243        0.003734
# 44       0.009665      0.000811         0.004434        0.003900
# 45       0.006045      0.004221         0.008057        0.003116
# 46       0.007645      0.003903         0.006455        0.004486
# 47       0.007648      0.003904         0.006046        0.004221
# 48       0.007651      0.002951         0.006453        0.003683
# 49       0.005255      0.003937         0.007652        0.003907
# 50       0.007649      0.003905         0.007654        0.002956
# 51       0.004026      0.003358         0.008465        0.003218
# 52       0.010061      0.005079         0.008462        0.003217
# 53       0.007644      0.002948         0.006441        0.004476
# 54       0.006048      0.003361         0.008871        0.006689
# 55       0.004843      0.004326         0.009274        0.000998
# 56       0.006047      0.004225         0.007649        0.002952
# 57       0.007648      0.003905         0.007649        0.002952
# 58       0.005636      0.004661         0.008462        0.003218
# 59       0.010275      0.005105         0.002009        0.004019
#
#    param_criterion param_max_features param_max_leaf_nodes param_splitter  \
# 0             gini               sqrt                    2           best
# 1             gini               sqrt                    2         random
# 2             gini               sqrt                    4           best
# 3             gini               sqrt                    4         random
# 4             gini               sqrt                    6           best
# 5             gini               sqrt                    6         random
# 6             gini               sqrt                    8           best
# 7             gini               sqrt                    8         random
# 8             gini               sqrt                   10           best
# 9             gini               sqrt                   10         random
# 10            gini               log2                    2           best
# 11            gini               log2                    2         random
# 12            gini               log2                    4           best
# 13            gini               log2                    4         random
# 14            gini               log2                    6           best
# 15            gini               log2                    6         random
# 16            gini               log2                    8           best
# 17            gini               log2                    8         random
# 18            gini               log2                   10           best
# 19            gini               log2                   10         random
# 20         entropy               sqrt                    2           best
# 21         entropy               sqrt                    2         random
# 22         entropy               sqrt                    4           best
# 23         entropy               sqrt                    4         random
# 24         entropy               sqrt                    6           best
# 25         entropy               sqrt                    6         random
# 26         entropy               sqrt                    8           best
# 27         entropy               sqrt                    8         random
# 28         entropy               sqrt                   10           best
# 29         entropy               sqrt                   10         random
# 30         entropy               log2                    2           best
# 31         entropy               log2                    2         random
# 32         entropy               log2                    4           best
# 33         entropy               log2                    4         random
# 34         entropy               log2                    6           best
# 35         entropy               log2                    6         random
# 36         entropy               log2                    8           best
# 37         entropy               log2                    8         random
# 38         entropy               log2                   10           best
# 39         entropy               log2                   10         random
# 40        log_loss               sqrt                    2           best
# 41        log_loss               sqrt                    2         random
# 42        log_loss               sqrt                    4           best
# 43        log_loss               sqrt                    4         random
# 44        log_loss               sqrt                    6           best
# 45        log_loss               sqrt                    6         random
# 46        log_loss               sqrt                    8           best
# 47        log_loss               sqrt                    8         random
# 48        log_loss               sqrt                   10           best
# 49        log_loss               sqrt                   10         random
# 50        log_loss               log2                    2           best
# 51        log_loss               log2                    2         random
# 52        log_loss               log2                    4           best
# 53        log_loss               log2                    4         random
# 54        log_loss               log2                    6           best
# 55        log_loss               log2                    6         random
# 56        log_loss               log2                    8           best
# 57        log_loss               log2                    8         random
# 58        log_loss               log2                   10           best
# 59        log_loss               log2                   10         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.759259
# 1   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.777778
# 2   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.814815
# 3   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.796296
# 4   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.814815
# 5   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.833333
# 6   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.851852
# 7   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.722222
# 8   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.833333
# 9   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.796296
# 10  {'criterion': 'gini', 'max_features': 'log2', ...           0.759259
# 11  {'criterion': 'gini', 'max_features': 'log2', ...           0.648148
# 12  {'criterion': 'gini', 'max_features': 'log2', ...           0.814815
# 13  {'criterion': 'gini', 'max_features': 'log2', ...           0.740741
# 14  {'criterion': 'gini', 'max_features': 'log2', ...           0.833333
# 15  {'criterion': 'gini', 'max_features': 'log2', ...           0.740741
# 16  {'criterion': 'gini', 'max_features': 'log2', ...           0.870370
# 17  {'criterion': 'gini', 'max_features': 'log2', ...           0.833333
# 18  {'criterion': 'gini', 'max_features': 'log2', ...           0.833333
# 19  {'criterion': 'gini', 'max_features': 'log2', ...           0.722222
# 20  {'criterion': 'entropy', 'max_features': 'sqrt...           0.648148
# 21  {'criterion': 'entropy', 'max_features': 'sqrt...           0.740741
# 22  {'criterion': 'entropy', 'max_features': 'sqrt...           0.851852
# 23  {'criterion': 'entropy', 'max_features': 'sqrt...           0.703704
# 24  {'criterion': 'entropy', 'max_features': 'sqrt...           0.870370
# 25  {'criterion': 'entropy', 'max_features': 'sqrt...           0.777778
# 26  {'criterion': 'entropy', 'max_features': 'sqrt...           0.870370
# 27  {'criterion': 'entropy', 'max_features': 'sqrt...           0.629630
# 28  {'criterion': 'entropy', 'max_features': 'sqrt...           0.833333
# 29  {'criterion': 'entropy', 'max_features': 'sqrt...           0.796296
# 30  {'criterion': 'entropy', 'max_features': 'log2...           0.814815
# 31  {'criterion': 'entropy', 'max_features': 'log2...           0.648148
# 32  {'criterion': 'entropy', 'max_features': 'log2...           0.777778
# 33  {'criterion': 'entropy', 'max_features': 'log2...           0.722222
# 34  {'criterion': 'entropy', 'max_features': 'log2...           0.870370
# 35  {'criterion': 'entropy', 'max_features': 'log2...           0.888889
# 36  {'criterion': 'entropy', 'max_features': 'log2...           0.814815
# 37  {'criterion': 'entropy', 'max_features': 'log2...           0.740741
# 38  {'criterion': 'entropy', 'max_features': 'log2...           0.833333
# 39  {'criterion': 'entropy', 'max_features': 'log2...           0.814815
# 40  {'criterion': 'log_loss', 'max_features': 'sqr...           0.814815
# 41  {'criterion': 'log_loss', 'max_features': 'sqr...           0.648148
# 42  {'criterion': 'log_loss', 'max_features': 'sqr...           0.851852
# 43  {'criterion': 'log_loss', 'max_features': 'sqr...           0.759259
# 44  {'criterion': 'log_loss', 'max_features': 'sqr...           0.870370
# 45  {'criterion': 'log_loss', 'max_features': 'sqr...           0.703704
# 46  {'criterion': 'log_loss', 'max_features': 'sqr...           0.888889
# 47  {'criterion': 'log_loss', 'max_features': 'sqr...           0.777778
# 48  {'criterion': 'log_loss', 'max_features': 'sqr...           0.851852
# 49  {'criterion': 'log_loss', 'max_features': 'sqr...           0.685185
# 50  {'criterion': 'log_loss', 'max_features': 'log...           0.759259
# 51  {'criterion': 'log_loss', 'max_features': 'log...           0.777778
# 52  {'criterion': 'log_loss', 'max_features': 'log...           0.870370
# 53  {'criterion': 'log_loss', 'max_features': 'log...           0.685185
# 54  {'criterion': 'log_loss', 'max_features': 'log...           0.851852
# 55  {'criterion': 'log_loss', 'max_features': 'log...           0.833333
# 56  {'criterion': 'log_loss', 'max_features': 'log...           0.870370
# 57  {'criterion': 'log_loss', 'max_features': 'log...           0.925926
# 58  {'criterion': 'log_loss', 'max_features': 'log...           0.814815
# 59  {'criterion': 'log_loss', 'max_features': 'log...           0.833333
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.811321           0.641509           0.811321
# 1            0.735849           0.641509           0.679245
# 2            0.811321           0.679245           0.811321
# 3            0.735849           0.773585           0.830189
# 4            0.849057           0.754717           0.943396
# 5            0.830189           0.660377           0.754717
# 6            0.867925           0.867925           0.867925
# 7            0.773585           0.792453           0.811321
# 8            0.849057           0.735849           0.867925
# 9            0.811321           0.641509           0.943396
# 10           0.792453           0.716981           0.641509
# 11           0.679245           0.641509           0.679245
# 12           0.811321           0.849057           0.943396
# 13           0.660377           0.679245           0.792453
# 14           0.867925           0.867925           0.943396
# 15           0.792453           0.622642           0.792453
# 16           0.811321           0.811321           0.905660
# 17           0.698113           0.698113           0.773585
# 18           0.867925           0.867925           0.924528
# 19           0.849057           0.811321           0.849057
# 20           0.660377           0.641509           0.811321
# 21           0.660377           0.641509           0.811321
# 22           0.792453           0.735849           0.943396
# 23           0.679245           0.698113           0.735849
# 24           0.867925           0.849057           0.905660
# 25           0.716981           0.735849           0.754717
# 26           0.792453           0.867925           0.905660
# 27           0.754717           0.641509           0.830189
# 28           0.830189           0.773585           0.849057
# 29           0.830189           0.735849           0.849057
# 30           0.811321           0.754717           0.811321
# 31           0.660377           0.641509           0.641509
# 32           0.735849           0.867925           0.867925
# 33           0.698113           0.660377           0.811321
# 34           0.811321           0.867925           0.792453
# 35           0.830189           0.679245           0.886792
# 36           0.886792           0.754717           0.886792
# 37           0.792453           0.773585           0.754717
# 38           0.886792           0.716981           0.943396
# 39           0.679245           0.679245           0.849057
# 40           0.792453           0.716981           0.886792
# 41           0.660377           0.660377           0.641509
# 42           0.811321           0.735849           0.943396
# 43           0.754717           0.679245           0.716981
# 44           0.792453           0.773585           0.886792
# 45           0.754717           0.811321           0.811321
# 46           0.792453           0.867925           0.943396
# 47           0.811321           0.716981           0.886792
# 48           0.867925           0.867925           0.943396
# 49           0.716981           0.698113           0.830189
# 50           0.792453           0.641509           0.641509
# 51           0.660377           0.641509           0.641509
# 52           0.811321           0.867925           0.811321
# 53           0.867925           0.716981           0.698113
# 54           0.867925           0.867925           0.886792
# 55           0.811321           0.679245           0.886792
# 56           0.905660           0.830189           0.943396
# 57           0.849057           0.792453           0.830189
# 58           0.773585           0.867925           0.943396
# 59           0.735849           0.716981           0.830189
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.886792         0.782041        0.081186               33
# 1            0.773585         0.721593        0.053423               52
# 2            0.886792         0.800699        0.067213               28
# 3            0.698113         0.766806        0.046065               41
# 4            0.943396         0.861076        0.073689               10
# 5            0.886792         0.793082        0.078564               30
# 6            0.754717         0.842068        0.044117               18
# 7            0.773585         0.774633        0.029707               38
# 8            0.981132         0.853459        0.078443               14
# 9            0.716981         0.781901        0.101072               34
# 10           0.886792         0.759399        0.081264               43
# 11           0.641509         0.657932        0.017571               59
# 12           0.886792         0.861076        0.049393               10
# 13           0.792453         0.733054        0.055304               49
# 14           0.792453         0.861006        0.049697               12
# 15           0.754717         0.740601        0.062435               48
# 16           0.905660         0.860867        0.042457               13
# 17           0.924528         0.785535        0.086060               32
# 18           0.962264         0.891195        0.046028                3
# 19           0.886792         0.823690        0.056067               24
# 20           0.792453         0.710762        0.074887               55
# 21           0.660377         0.702865        0.064144               56
# 22           0.886792         0.842068        0.072260               17
# 23           0.773585         0.718099        0.033196               53
# 24           0.981132         0.894829        0.046867                2
# 25           0.811321         0.759329        0.032892               44
# 26           0.735849         0.834451        0.061592               20
# 27           0.849057         0.741020        0.091783               47
# 28           0.867925         0.830818        0.031597               21
# 29           0.867925         0.815863        0.046481               26
# 30           0.641509         0.766737        0.066503               42
# 31           0.886792         0.695667        0.095811               57
# 32           0.792453         0.808386        0.052042               27
# 33           0.698113         0.718029        0.050671               54
# 34           0.981132         0.864640        0.065830                9
# 35           0.830189         0.823061        0.076393               25
# 36           0.867925         0.842208        0.051072               16
# 37           0.830189         0.778337        0.031247               35
# 38           0.754717         0.827044        0.083057               22
# 39           0.773585         0.759189        0.069512               45
# 40           0.641509         0.770510        0.084229               39
# 41           0.641509         0.650384        0.008512               60
# 42           0.867925         0.842068        0.068205               18
# 43           0.716981         0.725437        0.029250               50
# 44           0.905660         0.845772        0.052779               15
# 45           0.849057         0.786024        0.051009               31
# 46           0.962264         0.890985        0.060121                4
# 47           0.698113         0.778197        0.067899               36
# 48           0.905660         0.887352        0.033140                5
# 49           0.943396         0.774773        0.098739               37
# 50           0.792453         0.725437        0.069590               50
# 51           0.641509         0.672537        0.053126               58
# 52           0.981132         0.868414        0.062014                8
# 53           0.754717         0.744584        0.065978               46
# 54           0.924528         0.879804        0.024951                6
# 55           0.641509         0.770440        0.093919               40
# 56           0.981132         0.906150        0.053029                1
# 57           0.735849         0.826695        0.062904               23
# 58           0.962264         0.872397        0.072411                7
# 59           0.849057         0.793082        0.055131               29
